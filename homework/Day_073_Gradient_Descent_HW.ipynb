# %% [markdown]
# # 作業重點
#
# 使用function y=(x+5)² 來練習學習率( leanrning rate ) 調整所造成的影響

# %% [markdown]
# # 作業目標:
#     請嘗試使用不同的組合驗證 learning rate 對所需 iteration 的影響
#     lr = [0.1, 0.0001]
#     主要驗證 Lr 對於grandient 收斂的速度

# %%
cur_x = 3 # The algorithm starts at x=3
precision = 0.000001 #This tells us when to stop the algorithm
max_iters = 10000 # maximum number of iterations
df = lambda x: 2*(x+5) #Gradient of our function

# %%
'''
需要執行初始值設定, 下列三個
# Learning rate
#iteration counter
#Step size  
'''
'''
while previous_step_size > precision and iters < max_iters:

  算法迭代更新

print("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations
'''
# Out:
# '\nwhile previous_step_size > precision and iters < max_iters:\n\n  算法迭代更新\n\nprint("the learning rate is",lr, "\nIteration",iters,"\nX value is",cur_x) #Print iterations\n'

# %%
def check_lr(cur_x, precision, max_iters, df, lr):
    iters = 0
    iters_history = [iters]
    x_history = [cur_x]
    pres_x = cur_x
    cur_x -= lr * df(pres_x)
    step = abs(cur_x - pres_x)
    while step > precision and iters < max_iters:
        iters += 1
        iters_history.append(iters)
        x_history.append(cur_x)
        print(f'Iters: {iters}\nCurrent x: {cur_x}\tStep: {step}')
        pres_x = cur_x
        cur_x -= lr * df(pres_x)
        step = abs(cur_x - pres_x)
    return iters_history, x_history

# %%
iters_history_lr00001, x_history_lr00001 = check_lr(cur_x=cur_x, precision=precision, max_iters=max_iters, df=df, lr=0.0001)
# Out:
# Iters: 1
# Current x: 2.9984	Step: 0.0015999999999998238
# Iters: 2
# Current x: 2.99680032	Step: 0.0015996799999999922
# Iters: 3
# Current x: 2.995200959936	Step: 0.0015993600640000771
# Iters: 4
# Current x: 2.993601919744013	Step: 0.0015990401919872
# Iters: 5
# Current x: 2.992003199360064	Step: 0.0015987203839489261
# Iters: 6
# Current x: 2.990404798720192	Step: 0.001598400639871933
# Iters: 7
# Current x: 2.988806717760448	Step: 0.0015980809597442303
# Iters: 8
# Current x: 2.9872089564168958	Step: 0.001597761343552051
# Iters: 9
# Current x: 2.9856115146256124	Step: 0.001597441791283405
# Iters: 10
# Current x: 2.9840143923226874	Step: 0.0015971223029249693
# Iters: 11
# Current x: 2.9824175894442226	Step: 0.0015968028784647537
# Iters: 12
# Current x: 2.9808211059263336	Step: 0.0015964835178889913
# Iters: 13
# Current x: 2.9792249417051484	Step: 0.0015961642211852478
# Iters: 14
# Current x: 2.9776290967168073	Step: 0.0015958449883410886
# Iters: 15
# ...

# %%
iters_history_lr01, x_history_lr01 = check_lr(cur_x=cur_x, precision=precision, max_iters=max_iters, df=df, lr=0.1)
# Out:
# Iters: 1
# Current x: 1.4	Step: 1.6
# Iters: 2
# Current x: 0.11999999999999966	Step: 1.2800000000000002
# Iters: 3
# Current x: -0.9040000000000001	Step: 1.0239999999999998
# Iters: 4
# Current x: -1.7232000000000003	Step: 0.8192000000000002
# Iters: 5
# Current x: -2.3785600000000002	Step: 0.6553599999999999
# Iters: 6
# Current x: -2.902848	Step: 0.5242879999999999
# Iters: 7
# Current x: -3.3222784	Step: 0.4194304
# Iters: 8
# Current x: -3.65782272	Step: 0.3355443199999999
# Iters: 9
# Current x: -3.926258176	Step: 0.2684354560000002
# Iters: 10
# Current x: -4.1410065408	Step: 0.21474836480000015
# Iters: 11
# Current x: -4.312805232640001	Step: 0.1717986918400003
# Iters: 12
# Current x: -4.450244186112	Step: 0.13743895347199953
# Iters: 13
# Current x: -4.5601953488896	Step: 0.10995116277759998
# Iters: 14
# Current x: -4.64815627911168	Step: 0.08796093022207963
# Iters: 15
# Current x: -4.718525023289343	Step: 0.0703687441776637
# Iters: 16
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x_history_lr01)
plt.xlabel('$iters$', fontsize=16); plt.ylabel('$cur x$', fontsize=16)
plt.xticks(fontsize=16); plt.yticks(fontsize=16)
# Out:
# (array([-6., -5., -4., -3., -2., -1.,  0.,  1.,  2.,  3.,  4.]),
#  <a list of 11 Text yticklabel objects>)

# %%
plt.plot(x_history_lr00001)
plt.xlabel('$iters$', fontsize=16); plt.ylabel('$cur x$', fontsize=16)
plt.xticks(fontsize=16); plt.yticks(fontsize=16)
# Out:
# (array([-5., -4., -3., -2., -1.,  0.,  1.,  2.,  3.,  4.]),
#  <a list of 10 Text yticklabel objects>)
